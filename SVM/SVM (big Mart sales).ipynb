# %% [markdown]
# # SVM Classifier
#
# 16BCE1259
#
# Shushil Kumar Ravishankar

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns;sns.set()
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('clean_bmart.csv')

data=df.loc[(df['Outlet_Location_Type']=='Tier 1')|(df['Outlet_Location_Type']=='Tier 2')]
encoder=LabelEncoder()
encoder.fit(data['Outlet_Location_Type'])
y=encoder.transform(data['Outlet_Location_Type'])
y
# Out:
# array([0, 0, 1, ..., 1, 1, 0])

# %%
for i in range(len(y)):
    if y[i]==0:
        y[i]=-1
y
# Out:
# array([-1, -1,  1, ...,  1,  1, -1])

# %%
X=data.values[:,[6,12]]
scaler = StandardScaler()
scaler.fit(X)
X=scaler.transform(X)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
from sklearn.svm import SVC
model=SVC(C=0.00001,kernel='poly',max_iter=10000,random_state=0)
model.fit(X,y)
# Out:
# SVC(C=1e-05, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='poly',
#   max_iter=10000, probability=False, random_state=0, shrinking=True,
#   tol=0.001, verbose=False)

# %%
def plot_svc_decision_function(model,ax=None, plot_support=True):
    if ax is None:
        ax=plt.gca()
    xlim=ax.get_xlim()
    ylim=ax.get_ylim()
    
    x=np.linspace(xlim[0],xlim[1],30)
    y=np.linspace(ylim[0],ylim[1],30)
    Y,X=np.meshgrid(y,x)
    xy=np.vstack([X.ravel(),Y.ravel()]).T
    P=model.decision_function(xy).reshape(X.shape)
    
    ax.contour(X,Y,P,colors='k',levels=[-1,0,1],alpha=0.5,linestyles=['--','-','--'])
    
    if plot_support:
        ax.scatter(model.support_vectors_[:,0],model.support_vectors_[:,1],
                   s=300,linewidth=1,facecolors='none');
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

# %%
plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='autumn');
plot_svc_decision_function(model);

# %%
model=SVC(C=0.00001,kernel='rbf',max_iter=10000,random_state=0)
model.fit(X,y)
# Out:
# SVC(C=1e-05, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=10000, probability=False, random_state=0, shrinking=True,
#   tol=0.001, verbose=False)

# %%
plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='autumn');
plot_svc_decision_function(model);

# %%
model=SVC(C=0.00001,kernel='linear',max_iter=10000,random_state=0)
model.fit(X,y)
plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='autumn');
plot_svc_decision_function(model);

# %%
model=SVC(C=0.00001,kernel='sigmoid',max_iter=10000,random_state=0)
model.fit(X,y)
plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='autumn');
plot_svc_decision_function(model);

# %%
model=SVC(C=1,kernel='sigmoid',max_iter=10000,random_state=0)
model.fit(X,y)
plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='autumn');
plot_svc_decision_function(model);

# %%
model=SVC(C=1,gamma=0.5,kernel='sigmoid',max_iter=10000,random_state=0)
model.fit(X,y)
plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='autumn');
plot_svc_decision_function(model);

# %%
model=SVC(C=1,gamma=0.6,kernel='sigmoid',max_iter=10000,random_state=0)
model.fit(X,y)
plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='autumn');
plot_svc_decision_function(model);

# %%
model=SVC(C=1,gamma=0.9,kernel='sigmoid',max_iter=10000,random_state=0)
model.fit(X,y)
plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='autumn');
plot_svc_decision_function(model);

# %%
model=SVC(C=1,gamma=0.1,kernel='sigmoid',max_iter=10000,random_state=0)
model.fit(X,y)
plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='autumn');
plot_svc_decision_function(model);

# %%
model=SVC(C=1,gamma=1,kernel='sigmoid',max_iter=10000,random_state=0)
model.fit(X,y)
plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='autumn');
plot_svc_decision_function(model);
